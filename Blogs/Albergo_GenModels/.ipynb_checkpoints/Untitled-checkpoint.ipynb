# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
xz = np.linspace(-3,3,100)
xx = np.linspace(-3.8,3,100)
#xx = np.linspace(0,99,100)

yz =  (1 / (np.sqrt(2 * np.pi))) * np.exp(-(xz)**2 / 1)
yz2 = (1 / (np.sqrt(2 * np.pi))) * np.exp(-(xz2-80)**2 / 1)
#yy = np.abs((xx / 2  + 20) * (1/xz) * np.exp(-xx /20 )) + (200*yz2)

yy = np.abs((xx**4 - 10*xx**2 + xx + xx**3 - 25) +7)*(np.exp(-(xx-2)/20))
#x4−2x2+x

# %%
fig, [[ax1,ax2],[ax3,ax4]] = plt.subplots(2, 2, figsize=(20,15.5) )
fig.subplots_adjust(wspace=1.8)
fig.subplots_adjust(hspace=1.8)
ax1.plot(xz, yz, c='xkcd:blue', linewidth=4, alpha = 0.5)
ax1.text(-3.1, 0.38, r"$p(z) \sim \mathcal{N}(0,1)$", fontsize=13., color= 'xkcd:blue', alpha =0.7)
ax2.plot(xx, yy, c='xkcd:red', linewidth=4, alpha = 0.5)
ax2.text(-1.1, 65.38, r"$p(x)$", fontsize=13.5, color= 'xkcd:red', alpha =0.7)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.yaxis.tick_right()
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax1.set_xticklabels([])
ax1.set_yticklabels([])
ax2.set_xticks([])
ax2.set_yticks([])
ax1.set_xticks([])
ax1.set_yticks([])
#fig.tight_layout(pad=0)
#fig.subplots_adjust(wspace=1.8)
plt.show()
